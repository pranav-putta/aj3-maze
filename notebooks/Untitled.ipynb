# %%
import gym
import os
os.environ['MUJOCO_GL'] = 'glfw'

# %%
env = gym.make('memory_maze:MemoryMaze-9x9-Oracle-Top-v0')

# %%
state = env.reset()
# Out:
# WARNING:absl:Cannot set velocity on Entity with no free joint.

# %%
state
# Out:
# array([[[ 80, 137,  71],
#         [ 80, 137,  71],
#         [ 80, 137,  71],
#         ...,
#         [ 40,  68,  35],
#         [ 40,  68,  35],
#         [ 40,  68,  35]],
#
#        [[ 80, 137,  71],
#         [ 80, 137,  71],
#         [ 80, 137,  71],
#         ...,
#         [ 40,  68,  35],
#         [ 40,  68,  35],
#         [ 40,  68,  35]],
#
#        [[ 80, 137,  71],
#         [ 80, 137,  71],
#         [ 80, 137,  71],
#         ...,
#         [ 40,  68,  35],
#         [ 40,  68,  35],
#         [ 40,  68,  35]],
#
#        ...,
#
#        [[ 80, 137,  71],
#         [ 80, 137,  71],
#         [ 80, 137,  71],
#         ...,
#         [ 80, 137,  71],
#         [ 80, 137,  71],
#         [ 80, 137,  71]],
#
#        [[ 80, 137,  71],
#         [ 80, 137,  71],
#         [ 80, 137,  71],
#         ...,
#         [ 80, 137,  71],
#         [ 80, 137,  71],
#         [ 80, 137,  71]],
#
#        [[ 80, 137,  71],
#         [ 80, 137,  71],
#         [ 80, 137,  71],
# ...

# %%
from matplotlib import pyplot as plt
plt.imshow(state)

# %%
state, rewards, dones, infos = env.step(1)
# Out:
# /Users/pranavputta/mambaforge/envs/mazelens/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:219: DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /Users/pranavputta/mambaforge/envs/mazelens/lib/python3.11/site-packages/gym/utils/passive_env_checker.py:225: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):

# %%
plt.imshow(state)

# %%
infos
# Out:
# {}
